# %%
# cnn with more features
import os
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
X_train = []
X_test = []
y_train = []
y_test = []

# %%
source = "/Users/Kaede/Desktop/final_project/wav_files/guitar/"
files = [os.path.join(source, f) for f in os.listdir(source) if f.endswith('.wav')]
for i in range(len(files)):
    signal, sr = librosa.load(files[i])
    mfccs = librosa.feature.mfcc(y=signal, n_mfcc=40, sr=sr)
    mean_mfccs = np.mean(mfccs, axis=1)
    if i < 74:
        X_train.append(mean_mfccs)
        y_train.append(0)
    else:
        X_test.append(mean_mfccs)
        y_test.append(0)

# %%
source = "/Users/Kaede/Desktop/final_project/wav_files/flute/"
files = [os.path.join(source, f) for f in os.listdir(source) if f.endswith('.wav')]
for i in range(len(files)):
    signal, sr = librosa.load(files[i])
    mfccs = librosa.feature.mfcc(y=signal, n_mfcc=40, sr=sr)
    mean_mfccs = np.mean(mfccs, axis=1)
    if i < 618:
        X_train.append(mean_mfccs)
        y_train.append(1)
    else:
        X_test.append(mean_mfccs)
        y_test.append(1)

# %%
source = "/Users/Kaede/Desktop/final_project/wav_files/violin/"
files = [os.path.join(source, f) for f in os.listdir(source) if f.endswith('.wav')]
for i in range(len(files)):
    signal, sr = librosa.load(files[i])
    mfccs = librosa.feature.mfcc(y=signal, n_mfcc=40, sr=sr)
    mean_mfccs = np.mean(mfccs, axis=1)
    if i < 1051:
        X_train.append(mean_mfccs)
        y_train.append(2)
    else:
        X_test.append(mean_mfccs)
        y_test.append(2)

# %%
source = "/Users/Kaede/Desktop/final_project/wav_files/clarinet/"
files = [os.path.join(source, f) for f in os.listdir(source) if f.endswith('.wav')]
for i in range(len(files)):
    signal, sr = librosa.load(files[i])
    mfccs = librosa.feature.mfcc(y=signal, n_mfcc=40, sr=sr)
    mean_mfccs = np.mean(mfccs, axis=1)
    if i < 592:
        X_train.append(mean_mfccs)
        y_train.append(3)
    else:
        X_test.append(mean_mfccs)
        y_test.append(3)

# %%
source = "/Users/Kaede/Desktop/final_project/wav_files/trumpet/"
files = [os.path.join(source, f) for f in os.listdir(source) if f.endswith('.wav')]
for i in range(len(files)):
    signal, sr = librosa.load(files[i])
    mfccs = librosa.feature.mfcc(y=signal, n_mfcc=40, sr=sr)
    mean_mfccs = np.mean(mfccs, axis=1)
    if i < 339:
        X_train.append(mean_mfccs)
        y_train.append(4)
    else:
        X_test.append(mean_mfccs)
        y_test.append(4)

# %%
source = "/Users/Kaede/Desktop/final_project/wav_files/cello/"
files = [os.path.join(source, f) for f in os.listdir(source) if f.endswith('.wav')]
for i in range(len(files)):
    signal, sr = librosa.load(files[i])
    mfccs = librosa.feature.mfcc(y=signal, n_mfcc=40, sr=sr)
    mean_mfccs = np.mean(mfccs, axis=1)
    if i < 622:
        X_train.append(mean_mfccs)
        y_train.append(5)
    else:
        X_test.append(mean_mfccs)
        y_test.append(5)

# %%
source = "/Users/Kaede/Desktop/final_project/wav_files/saxophone/"
files = [os.path.join(source, f) for f in os.listdir(source) if f.endswith('.wav')]
for i in range(len(files)):
    signal, sr = librosa.load(files[i])
    mfccs = librosa.feature.mfcc(y=signal, n_mfcc=40, sr=sr)
    mean_mfccs = np.mean(mfccs, axis=1)
    if i < 512:
        X_train.append(mean_mfccs)
        y_train.append(6)
    else:
        X_test.append(mean_mfccs)
        y_test.append(6)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten, Conv1D, MaxPool1D, Flatten, LSTM
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# %%
import pandas as pd
class_num = 7
y_train = np.array(y_train)
y_test = np.array(y_test)
X_test = np.array(X_test)
X_train = np.array(X_train)
print(y_test.shape, y_train.shape, X_test.shape, X_train.shape)
# Out:
# (1636, 7) (3808, 7) (1636, 40) (3808, 40)

# %%
model = Sequential()
model.add(Conv1D(16, 3, activation='relu',strides=1, padding='same', input_shape=(40,1)))
model.add(Conv1D(32, 3, activation='relu', strides=1, padding='same'))
model.add(Conv1D(64, 3, activation='relu', strides=1, padding='same'))
model.add(Conv1D(128, 3, activation='relu', strides=1, padding='same'))

model.add(MaxPool1D(2))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(7, activation='softmax'))
# Out:
# 2022-07-22 01:20:42.173817: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 40, 16)            64
#
#  conv1d_1 (Conv1D)           (None, 40, 32)            1568
#
#  conv1d_2 (Conv1D)           (None, 40, 64)            6208
#
#  conv1d_3 (Conv1D)           (None, 40, 128)           24704
#
#  max_pooling1d (MaxPooling1D  (None, 20, 128)          0
#  )
#
#  dropout (Dropout)           (None, 20, 128)           0
#
#  flatten (Flatten)           (None, 2560)              0
#
#  dense (Dense)               (None, 128)               327808
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 369,063
# Trainable params: 369,063
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification_2.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

history = model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 116/119 [============================>.] - ETA: 0s - loss: 1.2230 - accuracy: 0.5902
# Epoch 1: val_loss improved from inf to 0.32762, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 2s 11ms/step - loss: 1.2046 - accuracy: 0.5956 - val_loss: 0.3276 - val_accuracy: 0.8814
# Epoch 2/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.3106 - accuracy: 0.8900
# Epoch 2: val_loss improved from 0.32762 to 0.22395, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.3114 - accuracy: 0.8900 - val_loss: 0.2240 - val_accuracy: 0.9211
# Epoch 3/100
# 115/119 [===========================>..] - ETA: 0s - loss: 0.1756 - accuracy: 0.9397
# Epoch 3: val_loss improved from 0.22395 to 0.11550, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.1753 - accuracy: 0.9391 - val_loss: 0.1155 - val_accuracy: 0.9633
# Epoch 4/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.1378 - accuracy: 0.9515
# Epoch 4: val_loss did not improve from 0.11550
# 119/119 [==============================] - 1s 9ms/step - loss: 0.1369 - accuracy: 0.9514 - val_loss: 0.1170 - val_accuracy: 0.9621
# Epoch 5/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.1306 - accuracy: 0.9550
# Epoch 5: val_loss improved from 0.11550 to 0.10496, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 10ms/step - loss: 0.1292 - accuracy: 0.9556 - val_loss: 0.1050 - val_accuracy: 0.9645
# Epoch 6/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0890 - accuracy: 0.9732
# Epoch 6: val_loss improved from 0.10496 to 0.08089, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0909 - accuracy: 0.9722 - val_loss: 0.0809 - val_accuracy: 0.9688
# Epoch 7/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0775 - accuracy: 0.9751
# Epoch 7: val_loss improved from 0.08089 to 0.07617, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0757 - accuracy: 0.9756 - val_loss: 0.0762 - val_accuracy: 0.9762
# Epoch 8/100
# 114/119 [===========================>..] - ETA: 0s - loss: 0.0666 - accuracy: 0.9745
# Epoch 8: val_loss improved from 0.07617 to 0.06639, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0646 - accuracy: 0.9756 - val_loss: 0.0664 - val_accuracy: 0.9829
# Epoch 9/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.0527 - accuracy: 0.9816
# Epoch 9: val_loss improved from 0.06639 to 0.06544, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0529 - accuracy: 0.9814 - val_loss: 0.0654 - val_accuracy: 0.9817
# Epoch 10/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9837
# Epoch 10: val_loss improved from 0.06544 to 0.05671, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0449 - accuracy: 0.9837 - val_loss: 0.0567 - val_accuracy: 0.9872
# Epoch 11/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0733 - accuracy: 0.9758
# Epoch 11: val_loss did not improve from 0.05671
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0717 - accuracy: 0.9764 - val_loss: 0.0618 - val_accuracy: 0.9811
# Epoch 12/100
# 114/119 [===========================>..] - ETA: 0s - loss: 0.0574 - accuracy: 0.9797
# Epoch 12: val_loss did not improve from 0.05671
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0574 - accuracy: 0.9798 - val_loss: 0.0622 - val_accuracy: 0.9835
# Epoch 13/100
# 115/119 [===========================>..] - ETA: 0s - loss: 0.0451 - accuracy: 0.9832
# Epoch 13: val_loss did not improve from 0.05671
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0451 - accuracy: 0.9832 - val_loss: 0.0676 - val_accuracy: 0.9804
# Epoch 14/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9825
# Epoch 14: val_loss did not improve from 0.05671
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0467 - accuracy: 0.9824 - val_loss: 0.0762 - val_accuracy: 0.9798
# Epoch 15/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9868
# Epoch 15: val_loss did not improve from 0.05671
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0393 - accuracy: 0.9866 - val_loss: 0.1278 - val_accuracy: 0.9609
# Epoch 16/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0477 - accuracy: 0.9831
# Epoch 16: val_loss did not improve from 0.05671
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0473 - accuracy: 0.9832 - val_loss: 0.0732 - val_accuracy: 0.9823
# Epoch 17/100
# 115/119 [===========================>..] - ETA: 0s - loss: 0.0283 - accuracy: 0.9899
# Epoch 17: val_loss did not improve from 0.05671
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0279 - accuracy: 0.9900 - val_loss: 0.0572 - val_accuracy: 0.9878
# Epoch 18/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 0.9952
# Epoch 18: val_loss did not improve from 0.05671
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0173 - accuracy: 0.9953 - val_loss: 0.0612 - val_accuracy: 0.9829
# Epoch 19/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9866
# Epoch 19: val_loss did not improve from 0.05671
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0393 - accuracy: 0.9866 - val_loss: 0.0671 - val_accuracy: 0.9829
# Epoch 20/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9921
# Epoch 20: val_loss improved from 0.05671 to 0.05421, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0289 - accuracy: 0.9921 - val_loss: 0.0542 - val_accuracy: 0.9859
# Epoch 21/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9934
# Epoch 21: val_loss did not improve from 0.05421
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.0594 - val_accuracy: 0.9841
# Epoch 22/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0513 - accuracy: 0.9820
# Epoch 22: val_loss did not improve from 0.05421
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0508 - accuracy: 0.9821 - val_loss: 0.0739 - val_accuracy: 0.9780
# Epoch 23/100
# 115/119 [===========================>..] - ETA: 0s - loss: 0.0374 - accuracy: 0.9878
# Epoch 23: val_loss did not improve from 0.05421
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0368 - accuracy: 0.9879 - val_loss: 0.0610 - val_accuracy: 0.9841
# Epoch 24/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0234 - accuracy: 0.9923
# Epoch 24: val_loss did not improve from 0.05421
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0226 - accuracy: 0.9926 - val_loss: 0.0759 - val_accuracy: 0.9768
# Epoch 25/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0280 - accuracy: 0.9906
# Epoch 25: val_loss did not improve from 0.05421
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0283 - accuracy: 0.9905 - val_loss: 0.0566 - val_accuracy: 0.9859
# Epoch 26/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9897
# Epoch 26: val_loss did not improve from 0.05421
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0318 - accuracy: 0.9892 - val_loss: 0.0957 - val_accuracy: 0.9749
# Epoch 27/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0374 - accuracy: 0.9886
# Epoch 27: val_loss did not improve from 0.05421
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.0711 - val_accuracy: 0.9811
# Epoch 28/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 0.9922
# Epoch 28: val_loss did not improve from 0.05421
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0216 - accuracy: 0.9921 - val_loss: 0.0727 - val_accuracy: 0.9823
# Epoch 29/100
# 114/119 [===========================>..] - ETA: 0s - loss: 0.0321 - accuracy: 0.9896
# Epoch 29: val_loss improved from 0.05421 to 0.05006, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 10ms/step - loss: 0.0309 - accuracy: 0.9900 - val_loss: 0.0501 - val_accuracy: 0.9866
# Epoch 30/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0252 - accuracy: 0.9920
# Epoch 30: val_loss did not improve from 0.05006
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0255 - accuracy: 0.9921 - val_loss: 0.0690 - val_accuracy: 0.9853
# Epoch 31/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0279 - accuracy: 0.9897
# Epoch 31: val_loss did not improve from 0.05006
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0276 - accuracy: 0.9898 - val_loss: 0.0685 - val_accuracy: 0.9829
# Epoch 32/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0276 - accuracy: 0.9914
# Epoch 32: val_loss did not improve from 0.05006
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0269 - accuracy: 0.9916 - val_loss: 0.0571 - val_accuracy: 0.9878
# Epoch 33/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0253 - accuracy: 0.9903
# Epoch 33: val_loss did not improve from 0.05006
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0247 - accuracy: 0.9903 - val_loss: 0.0782 - val_accuracy: 0.9817
# Epoch 34/100
# 115/119 [===========================>..] - ETA: 0s - loss: 0.0362 - accuracy: 0.9886
# Epoch 34: val_loss did not improve from 0.05006
# 119/119 [==============================] - 2s 18ms/step - loss: 0.0353 - accuracy: 0.9890 - val_loss: 0.0651 - val_accuracy: 0.9872
# Epoch 35/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9945
# Epoch 35: val_loss did not improve from 0.05006
# 119/119 [==============================] - 1s 12ms/step - loss: 0.0186 - accuracy: 0.9945 - val_loss: 0.0561 - val_accuracy: 0.9866
# Epoch 36/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0417 - accuracy: 0.9879
# Epoch 36: val_loss did not improve from 0.05006
# 119/119 [==============================] - 1s 10ms/step - loss: 0.0413 - accuracy: 0.9879 - val_loss: 0.0553 - val_accuracy: 0.9853
# Epoch 37/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.0241 - accuracy: 0.9923
# Epoch 37: val_loss improved from 0.05006 to 0.04885, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 10ms/step - loss: 0.0237 - accuracy: 0.9924 - val_loss: 0.0489 - val_accuracy: 0.9872
# Epoch 38/100
# 115/119 [===========================>..] - ETA: 0s - loss: 0.0207 - accuracy: 0.9935
# Epoch 38: val_loss improved from 0.04885 to 0.04679, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0203 - accuracy: 0.9937 - val_loss: 0.0468 - val_accuracy: 0.9890
# Epoch 39/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9941
# Epoch 39: val_loss did not improve from 0.04679
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.0806 - val_accuracy: 0.9792
# Epoch 40/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9953
# Epoch 40: val_loss did not improve from 0.04679
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.0674 - val_accuracy: 0.9847
# Epoch 41/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9961
# Epoch 41: val_loss did not improve from 0.04679
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.0591 - val_accuracy: 0.9859
# Epoch 42/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0222 - accuracy: 0.9928
# Epoch 42: val_loss did not improve from 0.04679
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0219 - accuracy: 0.9929 - val_loss: 0.0659 - val_accuracy: 0.9872
# Epoch 43/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9884
# Epoch 43: val_loss did not improve from 0.04679
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0431 - accuracy: 0.9884 - val_loss: 0.1322 - val_accuracy: 0.9652
# Epoch 44/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9913
# Epoch 44: val_loss did not improve from 0.04679
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0293 - accuracy: 0.9913 - val_loss: 0.0710 - val_accuracy: 0.9847
# Epoch 45/100
# 115/119 [===========================>..] - ETA: 0s - loss: 0.0237 - accuracy: 0.9921
# Epoch 45: val_loss did not improve from 0.04679
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0252 - accuracy: 0.9913 - val_loss: 0.0868 - val_accuracy: 0.9835
# Epoch 46/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9913
# Epoch 46: val_loss did not improve from 0.04679
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0264 - accuracy: 0.9913 - val_loss: 0.0543 - val_accuracy: 0.9847
# Epoch 47/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0083 - accuracy: 0.9964
# Epoch 47: val_loss improved from 0.04679 to 0.04480, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0079 - accuracy: 0.9966 - val_loss: 0.0448 - val_accuracy: 0.9896
# Epoch 48/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0115 - accuracy: 0.9967
# Epoch 48: val_loss did not improve from 0.04480
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.0813 - val_accuracy: 0.9841
# Epoch 49/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9897
# Epoch 49: val_loss did not improve from 0.04480
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0297 - accuracy: 0.9895 - val_loss: 0.0694 - val_accuracy: 0.9853
# Epoch 50/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9979
# Epoch 50: val_loss did not improve from 0.04480
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0759 - val_accuracy: 0.9829
# Epoch 51/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 0.9947
# Epoch 51: val_loss did not improve from 0.04480
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0147 - accuracy: 0.9947 - val_loss: 0.0918 - val_accuracy: 0.9817
# Epoch 52/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9934
# Epoch 52: val_loss did not improve from 0.04480
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0236 - accuracy: 0.9932 - val_loss: 0.0583 - val_accuracy: 0.9835
# Epoch 53/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0485 - accuracy: 0.9856
# Epoch 53: val_loss did not improve from 0.04480
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0488 - accuracy: 0.9858 - val_loss: 0.0540 - val_accuracy: 0.9859
# Epoch 54/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0252 - accuracy: 0.9919
# Epoch 54: val_loss did not improve from 0.04480
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0248 - accuracy: 0.9921 - val_loss: 0.0695 - val_accuracy: 0.9847
# Epoch 55/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0146 - accuracy: 0.9953
# Epoch 55: val_loss did not improve from 0.04480
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.0482 - val_accuracy: 0.9890
# Epoch 56/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9950
# Epoch 56: val_loss did not improve from 0.04480
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0511 - val_accuracy: 0.9896
# Epoch 57/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0196 - accuracy: 0.9942
# Epoch 57: val_loss did not improve from 0.04480
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0205 - accuracy: 0.9942 - val_loss: 0.0725 - val_accuracy: 0.9835
# Epoch 58/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0148 - accuracy: 0.9945
# Epoch 58: val_loss improved from 0.04480 to 0.03678, saving model to saved_models/audio_classification_2.hdf5
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0148 - accuracy: 0.9945 - val_loss: 0.0368 - val_accuracy: 0.9927
# Epoch 59/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9939
# Epoch 59: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0208 - accuracy: 0.9940 - val_loss: 0.0532 - val_accuracy: 0.9872
# Epoch 60/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9947
# Epoch 60: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0154 - accuracy: 0.9947 - val_loss: 0.0740 - val_accuracy: 0.9841
# Epoch 61/100
# 115/119 [===========================>..] - ETA: 0s - loss: 0.0284 - accuracy: 0.9913
# Epoch 61: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0287 - accuracy: 0.9913 - val_loss: 0.0487 - val_accuracy: 0.9872
# Epoch 62/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9938
# Epoch 62: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.0710 - val_accuracy: 0.9829
# Epoch 63/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0156 - accuracy: 0.9946
# Epoch 63: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0152 - accuracy: 0.9947 - val_loss: 0.0498 - val_accuracy: 0.9896
# Epoch 64/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9960
# Epoch 64: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0076 - accuracy: 0.9961 - val_loss: 0.0656 - val_accuracy: 0.9853
# Epoch 65/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9944
# Epoch 65: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0177 - accuracy: 0.9945 - val_loss: 0.0804 - val_accuracy: 0.9872
# Epoch 66/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0080 - accuracy: 0.9964
# Epoch 66: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0079 - accuracy: 0.9966 - val_loss: 0.0775 - val_accuracy: 0.9859
# Epoch 67/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0183 - accuracy: 0.9945
# Epoch 67: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0187 - accuracy: 0.9945 - val_loss: 0.1832 - val_accuracy: 0.9694
# Epoch 68/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0163 - accuracy: 0.9939
# Epoch 68: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0161 - accuracy: 0.9937 - val_loss: 0.0725 - val_accuracy: 0.9884
# Epoch 69/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0155 - accuracy: 0.9961
# Epoch 69: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0151 - accuracy: 0.9961 - val_loss: 0.0839 - val_accuracy: 0.9872
# Epoch 70/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0260 - accuracy: 0.9938
# Epoch 70: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0258 - accuracy: 0.9937 - val_loss: 0.0770 - val_accuracy: 0.9866
# Epoch 71/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0143 - accuracy: 0.9965
# Epoch 71: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0140 - accuracy: 0.9966 - val_loss: 0.0839 - val_accuracy: 0.9817
# Epoch 72/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9976
# Epoch 72: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0575 - val_accuracy: 0.9914
# Epoch 73/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9989
# Epoch 73: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0582 - val_accuracy: 0.9914
# Epoch 74/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9984
# Epoch 74: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.0907 - val_accuracy: 0.9859
# Epoch 75/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9937
# Epoch 75: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0259 - accuracy: 0.9937 - val_loss: 0.0690 - val_accuracy: 0.9866
# Epoch 76/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9971
# Epoch 76: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.0543 - val_accuracy: 0.9908
# Epoch 77/100
# 115/119 [===========================>..] - ETA: 0s - loss: 0.0243 - accuracy: 0.9932
# Epoch 77: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0235 - accuracy: 0.9934 - val_loss: 0.1045 - val_accuracy: 0.9817
# Epoch 78/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9932
# Epoch 78: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.1046 - val_accuracy: 0.9804
# Epoch 79/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9947
# Epoch 79: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0159 - accuracy: 0.9947 - val_loss: 0.0793 - val_accuracy: 0.9872
# Epoch 80/100
# 114/119 [===========================>..] - ETA: 0s - loss: 0.0363 - accuracy: 0.9910
# Epoch 80: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0350 - accuracy: 0.9913 - val_loss: 0.0621 - val_accuracy: 0.9890
# Epoch 81/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9950
# Epoch 81: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0135 - accuracy: 0.9950 - val_loss: 0.0643 - val_accuracy: 0.9859
# Epoch 82/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0063 - accuracy: 0.9981
# Epoch 82: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0678 - val_accuracy: 0.9884
# Epoch 83/100
# 114/119 [===========================>..] - ETA: 0s - loss: 0.0208 - accuracy: 0.9945
# Epoch 83: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0208 - accuracy: 0.9945 - val_loss: 0.0447 - val_accuracy: 0.9927
# Epoch 84/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0027 - accuracy: 0.9989
# Epoch 84: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.0492 - val_accuracy: 0.9902
# Epoch 85/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0117 - accuracy: 0.9964
# Epoch 85: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.0936 - val_accuracy: 0.9835
# Epoch 86/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9939
# Epoch 86: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0230 - accuracy: 0.9940 - val_loss: 0.0652 - val_accuracy: 0.9866
# Epoch 87/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9987
# Epoch 87: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.0601 - val_accuracy: 0.9902
# Epoch 88/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0085 - accuracy: 0.9967
# Epoch 88: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0091 - accuracy: 0.9966 - val_loss: 0.0555 - val_accuracy: 0.9896
# Epoch 89/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0181 - accuracy: 0.9956
# Epoch 89: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0172 - accuracy: 0.9958 - val_loss: 0.0543 - val_accuracy: 0.9896
# Epoch 90/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.0115 - accuracy: 0.9979
# Epoch 90: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0114 - accuracy: 0.9979 - val_loss: 0.0659 - val_accuracy: 0.9878
# Epoch 91/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.0199 - accuracy: 0.9944
# Epoch 91: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0202 - accuracy: 0.9942 - val_loss: 0.0986 - val_accuracy: 0.9829
# Epoch 92/100
# 114/119 [===========================>..] - ETA: 0s - loss: 0.0168 - accuracy: 0.9926
# Epoch 92: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0161 - accuracy: 0.9929 - val_loss: 0.0606 - val_accuracy: 0.9884
# Epoch 93/100
# 116/119 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9946
# Epoch 93: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0185 - accuracy: 0.9947 - val_loss: 0.1010 - val_accuracy: 0.9829
# Epoch 94/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0145 - accuracy: 0.9963
# Epoch 94: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0144 - accuracy: 0.9963 - val_loss: 0.0772 - val_accuracy: 0.9841
# Epoch 95/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0158 - accuracy: 0.9953
# Epoch 95: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.0683 - val_accuracy: 0.9847
# Epoch 96/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0130 - accuracy: 0.9975
# Epoch 96: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0125 - accuracy: 0.9976 - val_loss: 0.0567 - val_accuracy: 0.9866
# Epoch 97/100
# 118/119 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9981
# Epoch 97: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0083 - accuracy: 0.9982 - val_loss: 0.0679 - val_accuracy: 0.9872
# Epoch 98/100
# 113/119 [===========================>..] - ETA: 0s - loss: 0.0096 - accuracy: 0.9967
# Epoch 98: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0091 - accuracy: 0.9968 - val_loss: 0.0661 - val_accuracy: 0.9884
# Epoch 99/100
# 117/119 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9952
# Epoch 99: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 9ms/step - loss: 0.0147 - accuracy: 0.9953 - val_loss: 0.0707 - val_accuracy: 0.9884
# Epoch 100/100
# 119/119 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9979
# Epoch 100: val_loss did not improve from 0.03678
# 119/119 [==============================] - 1s 8ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0821 - val_accuracy: 0.9866
# Training completed in time:  0:01:48.338419

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.9865525960922241
